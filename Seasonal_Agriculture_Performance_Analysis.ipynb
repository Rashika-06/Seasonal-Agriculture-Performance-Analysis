# %%
# %pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/10.0 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/10.0 MB 2.0 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.0/10.0 MB 1.8 MB/s eta 0:00:06
#    ------ --------------------------------- 1.6/10.0 MB 1.9 MB/s eta 0:00:05
#    -------- ------------------------------- 2.1/10.0 MB 2.1 MB/s eta 0:00:04
#    --------- ------------------------------ 2.4/10.0 MB 1.9 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.9/10.0 MB 2.0 MB/s eta 0:00:04
#    ------------- -------------------------- 3.4/10.0 MB 2.1 MB/s eta 0:00:04
#    --------------- ------------------------ 3.9/10.0 MB 2.1 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.2/10.0 MB 2.1 MB/s eta 0:00:03
#    ------------------ --------------------- 4.7/10.0 MB 2.1 MB/s eta 0:00:03
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("seasonal_agriculture_performance_dataset.csv")

# %%
df.head()
# Out:
#    Farm_ID           State  District    Crop  Season  Farm_Area_Hectares  \
# 0  SF10001  Andhra Pradesh    Rajkot   Wheat  Kharif                0.53
# 1  SF10002     Maharashtra  Nalgonda   Maize  Kharif                6.53
# 2  SF10003       Telangana  Warangal  Pulses    Rabi                4.86
# 3  SF10004       Telangana    Indore    Rice  Kharif                4.50
# 4  SF10005       Karnataka  Ludhiana   Maize    Zaid                4.21
#
#    Rainfall_mm  Avg_Temperature_C  Humidity_pct  Sunlight_Hours_Day  ...  \
# 0        486.4               24.3          69.1                 5.8  ...
# 1        855.4               25.7          78.4                 5.1  ...
# 2        455.6               23.9          56.4                10.3  ...
# 3        753.2               29.7          65.2                 6.3  ...
# 4        101.6               34.1          55.2                 6.5  ...
#
#    Seed_Quality_Score  Yield_Tonnes_Ha  Production_Tonnes  \
# ...

# %%
df.shape
# Out:
# (4000, 28)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Farm_ID                        4000 non-null   str
#  1   State                          4000 non-null   str
#  2   District                       4000 non-null   str
#  3   Crop                           4000 non-null   str
#  4   Season                         4000 non-null   str
#  5   Farm_Area_Hectares             4000 non-null   float64
#  6   Rainfall_mm                    3952 non-null   float64
#  7   Avg_Temperature_C              4000 non-null   float64
#  8   Humidity_pct                   4000 non-null   float64
#  9   Sunlight_Hours_Day             4000 non-null   float64
#  10  Soil_pH                        4000 non-null   float64
#  11  Soil_Moisture_pct              3960 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# Farm_ID                           0
# State                             0
# District                          0
# Crop                              0
# Season                            0
# Farm_Area_Hectares                0
# Rainfall_mm                      48
# Avg_Temperature_C                 0
# Humidity_pct                      0
# Sunlight_Hours_Day                0
# Soil_pH                           0
# Soil_Moisture_pct                40
# Nitrogen_kg_ha                    0
# Phosphorus_kg_ha                  0
# Potassium_kg_ha                   0
# Irrigation_Method                 0
# Fertilizer_kg_ha                  0
# Pesticide_Litre_ha                0
# Seed_Quality_Score                0
# Yield_Tonnes_Ha                  32
# Production_Tonnes                 0
# Market_Price_INR_Tonne            0
# Total_Cost_INR                    0
# Revenue_INR                       0
# Profit_INR                        0
# Water_Used_m3                     0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Rainfall_mm'] = df['Rainfall_mm'].fillna(df['Rainfall_mm'].median())

df['Soil_Moisture_pct'] = df['Soil_Moisture_pct'].fillna(df['Soil_Moisture_pct'].median())

df['Yield_Tonnes_Ha'] = df['Yield_Tonnes_Ha'].fillna(df['Yield_Tonnes_Ha'].median())

# %%
df.isnull().sum()
# Out:
# Farm_ID                          0
# State                            0
# District                         0
# Crop                             0
# Season                           0
# Farm_Area_Hectares               0
# Rainfall_mm                      0
# Avg_Temperature_C                0
# Humidity_pct                     0
# Sunlight_Hours_Day               0
# Soil_pH                          0
# Soil_Moisture_pct                0
# Nitrogen_kg_ha                   0
# Phosphorus_kg_ha                 0
# Potassium_kg_ha                  0
# Irrigation_Method                0
# Fertilizer_kg_ha                 0
# Pesticide_Litre_ha               0
# Seed_Quality_Score               0
# Yield_Tonnes_Ha                  0
# Production_Tonnes                0
# Market_Price_INR_Tonne           0
# Total_Cost_INR                   0
# Revenue_INR                      0
# Profit_INR                       0
# Water_Used_m3                    0
# Water_Efficiency_t_per_1000m3    0
# ...

# %%
df.describe()
# Out:
#        Farm_Area_Hectares  Rainfall_mm  Avg_Temperature_C  Humidity_pct  \
# count         4000.000000  4000.000000         4000.00000   4000.000000
# mean             7.888265   600.922825           26.81890     63.210500
# std              4.223764   287.193381            3.81818     11.960834
# min              0.500000    80.000000           16.20000     25.000000
# 25%              4.260000   371.575000           23.90000     54.775000
# 50%              7.895000   582.000000           26.90000     63.000000
# 75%             11.650000   831.975000           29.60000     71.900000
# max             15.000000  1395.200000           39.70000     95.000000
#
#        Sunlight_Hours_Day      Soil_pH  Soil_Moisture_pct  Nitrogen_kg_ha  \
# count         4000.000000  4000.000000        4000.000000     4000.000000
# mean             7.323050     6.701010          26.507150      120.250825
# std              1.121186     0.641461           6.678837       31.216452
# ...

# %%
print("Seasons:")
print(df['Season'].unique())

print("\nCrops:")
print(df['Crop'].unique())

print("\nIrrigation Methods:")
print(df['Irrigation_Method'].unique())
# Out:
# Seasons:
# <StringArray>
# ['Kharif', 'Rabi', 'Zaid']
# Length: 3, dtype: str
#
# Crops:
# <StringArray>
# [    'Wheat',     'Maize',    'Pulses',      'Rice',    'Cotton',    'Chilli',
#  'Groundnut', 'Sugarcane']
# Length: 8, dtype: str
#
# Irrigation Methods:
# <StringArray>
# ['Drip', 'Flood', 'Rainfed', 'Sprinkler']
# Length: 4, dtype: str

# %%
season_yield = df.groupby('Season')['Yield_Tonnes_Ha'].mean()
season_yield
# Out:
# Season
# Kharif    5.628612
# Rabi      5.039435
# Zaid      4.641313
# Name: Yield_Tonnes_Ha, dtype: float64

# %%
season_yield.idxmax()
# Out:
# 'Kharif'

# %%
crop_yield = df.groupby('Crop')['Yield_Tonnes_Ha'].mean()
crop_yield
# Out:
# Crop
# Chilli        1.542767
# Cotton        1.229783
# Groundnut     1.322901
# Maize         2.710036
# Pulses        0.921512
# Rice          2.431304
# Sugarcane    46.642361
# Wheat         2.108013
# Name: Yield_Tonnes_Ha, dtype: float64

# %%
crop_yield.idxmax()
# Out:
# 'Sugarcane'

# %%
crop_yield.max()
# Out:
# np.float64(46.642360655737704)

# %%
# %pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.5 MB 6.2 MB/s eta 0:00:02
#    ------- -------------------------------- 1.8/9.5 MB 5.9 MB/s eta 0:00:02
#    ------------ --------------------------- 2.9/9.5 MB 5.2 MB/s eta 0:00:02
#    -------------- ------------------------- 3.4/9.5 MB 4.4 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.9/9.5 MB 4.0 MB/s eta 0:00:02
#    ------------------ --------------------- 4.5/9.5 MB 3.8 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.2/9.5 MB 3.7 MB/s eta 0:00:02
#    ------------------------ --------------- 5.8/9.5 MB 3.6 MB/s eta 0:00:02
#    --------------------------- ------------ 6.6/9.5 MB 3.7 MB/s eta 0:00:01
#    ------------------------------- -------- 7.6/9.5 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.1/9.5 MB 3.7 MB/s eta 0:00:01
# ...

# %%
import matplotlib.pyplot as plt

# %%
season_yield.plot(kind='bar')

plt.title('Average Crop Yield by Season')
plt.xlabel('Season')
plt.ylabel('Average Yield (Tonnes/Ha)')
plt.xticks(rotation=0)
plt.show()

# %%
season_profit = df.groupby('Season')['Profit_INR'].mean()
season_profit
# Out:
# Season
# Kharif    178914.647555
# Rabi       87689.470191
# Zaid      -24804.824916
# Name: Profit_INR, dtype: float64

# %%
season_profit.idxmax()
# Out:
# 'Kharif'

# %%
crop_profit = df.groupby('Crop')['Profit_INR'].mean()
crop_profit
# Out:
# Crop
# Chilli       750878.342233
# Cotton       124546.915354
# Groundnut     44858.120283
# Maize        -83978.326679
# Pulses        -4238.052419
# Rice        -102213.504348
# Sugarcane    817187.986885
# Wheat       -123398.337134
# Name: Profit_INR, dtype: float64

# %%
crop_profit.idxmax()
# Out:
# 'Sugarcane'

# %%
crop_profit.max()
# Out:
# np.float64(817187.9868852459)

# %%
df['Rainfall_mm'].corr(df['Yield_Tonnes_Ha'])
# Out:
# np.float64(0.030950993551650857)

# %%
plt.scatter(df['Rainfall_mm'], df['Yield_Tonnes_Ha'])

plt.title('Rainfall vs Crop Yield')
plt.xlabel('Rainfall (mm)')
plt.ylabel('Yield (Tonnes/Ha)')
plt.show()

# %%
irrigation_efficiency = df.groupby('Irrigation_Method')['Water_Efficiency_t_per_1000m3'].mean()
irrigation_efficiency
# Out:
# Irrigation_Method
# Drip         6.267129
# Flood        3.438853
# Rainfed      7.563784
# Sprinkler    4.669805
# Name: Water_Efficiency_t_per_1000m3, dtype: float64

# %%
irrigation_efficiency.idxmax()
# Out:
# 'Rainfed'

# %%
irrigation_efficiency.max()
# Out:
# np.float64(7.56378386167147)

# %%
df['Fertilizer_kg_ha'].corr(df['Yield_Tonnes_Ha'])
# Out:
# np.float64(1.7712703696046227e-05)

# %%
plt.scatter(df['Fertilizer_kg_ha'], df['Yield_Tonnes_Ha'])

plt.title('Fertilizer Usage vs Crop Yield')
plt.xlabel('Fertilizer (kg/ha)')
plt.ylabel('Yield (Tonnes/Ha)')
plt.show()

# %%
season_risk = df.groupby('Season')['Disease_Pest_Risk_pct'].mean()
season_risk
# Out:
# Season
# Kharif    54.467903
# Rabi      40.482114
# Zaid      38.216667
# Name: Disease_Pest_Risk_pct, dtype: float64

# %%
season_risk.idxmax()
# Out:
# 'Kharif'

# %%
season_risk.max()
# Out:
# np.float64(54.46790331646992)

# %%
crop_season_yield = df.groupby(['Season', 'Crop'])['Yield_Tonnes_Ha'].mean()
crop_season_yield
# Out:
# Season  Crop
# Kharif  Chilli        1.731459
#         Cotton        1.374512
#         Groundnut     1.484974
#         Maize         2.966410
#         Pulses        1.036063
#         Rice          2.698376
#         Sugarcane    53.459120
#         Wheat         2.253664
# Rabi    Chilli        1.465031
#         Cotton        1.198358
#         Groundnut     1.233164
#         Maize         2.603648
#         Pulses        0.875962
#         Rice          2.322847
#         Sugarcane    43.286124
#         Wheat         2.057468
# Zaid    Chilli        1.195312
#         Cotton        0.960217
#         Groundnut     1.037778
#         Maize         2.290952
#         Pulses        0.669677
#         Rice          1.900490
#         Sugarcane    38.423922
#         Wheat         1.748588
# Name: Yield_Tonnes_Ha, dtype: float64

# %%
crop_season_table = df.pivot_table(
    values='Yield_Tonnes_Ha',
    index='Crop',
    columns='Season',
    aggfunc='mean'
)

crop_season_table
# Out:
# Season        Kharif       Rabi       Zaid
# Crop
# Chilli      1.731459   1.465031   1.195312
# Cotton      1.374512   1.198358   0.960217
# Groundnut   1.484974   1.233164   1.037778
# Maize       2.966410   2.603648   2.290952
# Pulses      1.036063   0.875962   0.669677
# Rice        2.698376   2.322847   1.900490
# Sugarcane  53.459120  43.286124  38.423922
# Wheat       2.253664   2.057468   1.748588

# %%
best_crop_each_season = df.loc[
    df.groupby('Season')['Yield_Tonnes_Ha'].idxmax(),
    ['Season', 'Crop', 'Yield_Tonnes_Ha']
]

best_crop_each_season
# Out:
#       Season       Crop  Yield_Tonnes_Ha
# 1715  Kharif  Sugarcane           101.44
# 3525    Rabi  Sugarcane            93.13
# 646     Zaid  Sugarcane            64.76

# %%
crop_season_profit = df.groupby(
    ['Season', 'Crop']
)['Profit_INR'].mean()

crop_season_profit
# Out:
# Season  Crop
# Kharif  Chilli       9.543804e+05
#         Cotton       2.169995e+05
#         Groundnut    1.082654e+05
#         Maize       -3.933267e+04
#         Pulses       4.333890e+04
#         Rice        -6.490340e+04
#         Sugarcane    1.000791e+06
#         Wheat       -1.058719e+05
# Rabi    Chilli       6.385725e+05
#         Cotton       1.073436e+05
#         Groundnut    1.041654e+04
#         Maize       -8.913340e+04
#         Pulses      -1.430914e+04
#         Rice        -9.842787e+04
#         Sugarcane    7.316129e+05
#         Wheat       -1.199546e+05
# Zaid    Chilli       4.486591e+05
#         Cotton      -5.392534e+04
#         Groundnut   -6.887250e+04
#         Maize       -1.940492e+05
#         Pulses      -1.392278e+05
#         Rice        -2.272393e+05
#         Sugarcane    5.836358e+05
#         Wheat       -1.932090e+05
# Name: Profit_INR, dtype: float64

# %%
best_profit_each_season = df.loc[
    df.groupby('Season')['Profit_INR'].idxmax(),
    ['Season', 'Crop', 'Profit_INR']
]

best_profit_each_season
# Out:
#       Season       Crop  Profit_INR
# 2236  Kharif     Chilli     4345421
# 357     Rabi  Sugarcane     3378879
# 1616    Zaid  Sugarcane     2349990

# %%
irrigation_yield = df.groupby('Irrigation_Method')['Yield_Tonnes_Ha'].mean()

irrigation_yield
# Out:
# Irrigation_Method
# Drip         6.577989
# Flood        4.863977
# Rainfed      4.602142
# Sprinkler    5.160627
# Name: Yield_Tonnes_Ha, dtype: float64

# %%
irrigation_yield.idxmax(), irrigation_yield.max()
# Out:
# ('Drip', np.float64(6.577989071038251))

# %%
irrigation_yield.plot(kind='bar')

plt.title('Average Crop Yield by Irrigation Method')
plt.xlabel('Irrigation Method')
plt.ylabel('Average Yield (Tonnes/Ha)')
plt.xticks(rotation=0)
plt.show()

# %%
season_risk = df.groupby('Season')['Disease_Pest_Risk_pct'].mean()

season_risk
# Out:
# Season
# Kharif    54.467903
# Rabi      40.482114
# Zaid      38.216667
# Name: Disease_Pest_Risk_pct, dtype: float64

# %%
season_risk.idxmax(), season_risk.max()
# Out:
# ('Kharif', np.float64(54.46790331646992))

# %%
season_risk.plot(kind='bar')

plt.title('Average Disease and Pest Risk by Season')
plt.xlabel('Season')
plt.ylabel('Disease/Pest Risk (%)')
plt.xticks(rotation=0)
plt.show()

# %%
soil_moisture_yield_corr = df['Soil_Moisture_pct'].corr(
    df['Yield_Tonnes_Ha']
)

soil_moisture_yield_corr
# Out:
# np.float64(0.010999346063015851)

# %%
plt.scatter(
    df['Soil_Moisture_pct'],
    df['Yield_Tonnes_Ha']
)

plt.title('Soil Moisture vs Crop Yield')
plt.xlabel('Soil Moisture (%)')
plt.ylabel('Yield (Tonnes/Ha)')
plt.show()

# %%
fertilizer_yield_corr = df['Fertilizer_kg_ha'].corr(
    df['Yield_Tonnes_Ha']
)

fertilizer_yield_corr
# Out:
# np.float64(1.7712703696046227e-05)

# %%
plt.scatter(
    df['Fertilizer_kg_ha'],
    df['Yield_Tonnes_Ha']
)

plt.title('Fertilizer Usage vs Crop Yield')
plt.xlabel('Fertilizer (kg/ha)')
plt.ylabel('Yield (Tonnes/Ha)')
plt.show()

# %%
market_profit_corr = df['Market_Price_INR_Tonne'].corr(
    df['Profit_INR']
)

market_profit_corr
# Out:
# np.float64(0.22511939019981006)

# %%
plt.scatter(
    df['Market_Price_INR_Tonne'],
    df['Profit_INR']
)

plt.title('Market Price vs Profit')
plt.xlabel('Market Price (INR/Tonne)')
plt.ylabel('Profit (INR)')
plt.show()

# %%
season_production = df.groupby('Season')['Production_Tonnes'].mean()

season_production
# Out:
# Season
# Kharif    46.311192
# Rabi      41.486712
# Zaid      38.886111
# Name: Production_Tonnes, dtype: float64

# %%
season_production.idxmax(), season_production.max()
# Out:
# ('Kharif', np.float64(46.3111916807195))

# %%
season_production.plot(kind='bar')

plt.title('Average Agricultural Production by Season')
plt.xlabel('Season')
plt.ylabel('Production (Tonnes)')
plt.xticks(rotation=0)
plt.show()

# %%
water_efficiency = df.groupby('Irrigation_Method')['Water_Efficiency_t_per_1000m3'].mean()

water_efficiency
# Out:
# Irrigation_Method
# Drip         6.267129
# Flood        3.438853
# Rainfed      7.563784
# Sprinkler    4.669805
# Name: Water_Efficiency_t_per_1000m3, dtype: float64

# %%
water_efficiency.idxmax(), water_efficiency.max()
# Out:
# ('Rainfed', np.float64(7.56378386167147))

# %%
water_efficiency.plot(kind='bar')

plt.title('Water Efficiency by Irrigation Method')
plt.xlabel('Irrigation Method')
plt.ylabel('Water Efficiency (Tonnes per 1000 m³)')
plt.xticks(rotation=0)
plt.show()

# %%
irrigation_profit = df.groupby('Irrigation_Method')['Profit_INR'].mean()

irrigation_profit
# Out:
# Irrigation_Method
# Drip         219625.997814
# Flood         73354.022901
# Rainfed       79050.365034
# Sprinkler     91121.079019
# Name: Profit_INR, dtype: float64

# %%
irrigation_profit.idxmax(), irrigation_profit.max()
# Out:
# ('Drip', np.float64(219625.99781420766))

# %%
irrigation_profit.plot(kind='bar')

plt.title('Average Profit by Irrigation Method')
plt.xlabel('Irrigation Method')
plt.ylabel('Average Profit (INR)')
plt.xticks(rotation=0)
plt.show()

# %%
crop_yield = df.groupby('Crop')['Yield_Tonnes_Ha'].mean()

crop_yield
# Out:
# Crop
# Chilli        1.542767
# Cotton        1.229783
# Groundnut     1.322901
# Maize         2.710036
# Pulses        0.921512
# Rice          2.431304
# Sugarcane    46.642361
# Wheat         2.108013
# Name: Yield_Tonnes_Ha, dtype: float64

# %%
crop_yield.sort_values().plot(kind='bar')

plt.title('Average Crop Yield by Crop')
plt.xlabel('Crop')
plt.ylabel('Average Yield (Tonnes/Ha)')
plt.xticks(rotation=45)
plt.show()

# %%
print("Highest yielding crop:", crop_yield.idxmax())
print("Highest average yield:", crop_yield.max())

print("Lowest yielding crop:", crop_yield.idxmin())
print("Lowest average yield:", crop_yield.min())
# Out:
# Highest yielding crop: Sugarcane
# Highest average yield: 46.642360655737704
# Lowest yielding crop: Pulses
# Lowest average yield: 0.9215120967741935

# %%
season_financial = df.groupby('Season')[
    ['Total_Cost_INR', 'Revenue_INR']
].mean()

season_financial
# Out:
#         Total_Cost_INR    Revenue_INR
# Season
# Kharif   531804.408094  710719.055649
# Rabi     513836.578365  601526.048556
# Zaid     543976.728956  519171.904040

# %%
season_financial.plot(kind='bar')

plt.title('Average Cost and Revenue by Season')
plt.xlabel('Season')
plt.ylabel('Amount (INR)')
plt.xticks(rotation=0)
plt.show()

# %%
season_financial
# Out:
#         Total_Cost_INR    Revenue_INR
# Season
# Kharif   531804.408094  710719.055649
# Rabi     513836.578365  601526.048556
# Zaid     543976.728956  519171.904040

# %%
summary = {
    'Analysis': [
        'Highest Yield Season',
        'Highest Yielding Crop',
        'Highest Profit Crop',
        'Highest Production Season'
    ],
    'Result': [
        season_yield.idxmax(),
        crop_yield.idxmax(),
        crop_profit.idxmax(),
        season_production.idxmax()
    ]
}

summary_df = pd.DataFrame(summary)

summary_df
# Out:
#                     Analysis     Result
# 0       Highest Yield Season     Kharif
# 1      Highest Yielding Crop  Sugarcane
# 2        Highest Profit Crop  Sugarcane
# 3  Highest Production Season     Kharif

# %%
print("===== SEASONAL AGRICULTURE PERFORMANCE ANALYSIS =====")

print("\n1. Highest Average Yield Season:")
print(season_yield.idxmax(), "with", round(season_yield.max(), 2), "tonnes/ha")

print("\n2. Highest Average Yield Crop:")
print(crop_yield.idxmax(), "with", round(crop_yield.max(), 2), "tonnes/ha")

print("\n3. Highest Average Profit Crop:")
print(crop_profit.idxmax(), "with ₹", round(crop_profit.max(), 2))

print("\n4. Highest Production Season:")
print(season_production.idxmax(), "with", round(season_production.max(), 2), "tonnes")

print("\n5. Rainfall vs Yield Correlation:")
print(round(df['Rainfall_mm'].corr(df['Yield_Tonnes_Ha']), 3))

print("\n6. Fertilizer vs Yield Correlation:")
print(round(df['Fertilizer_kg_ha'].corr(df['Yield_Tonnes_Ha']), 3))

print("\n7. Soil Moisture vs Yield Correlation:")
print(round(df['Soil_Moisture_pct'].corr(df['Yield_Tonnes_Ha']), 3))
# Out:
# ===== SEASONAL AGRICULTURE PERFORMANCE ANALYSIS =====
#
# 1. Highest Average Yield Season:
# Kharif with 5.63 tonnes/ha
#
# 2. Highest Average Yield Crop:
# Sugarcane with 46.64 tonnes/ha
#
# 3. Highest Average Profit Crop:
# Sugarcane with ₹ 817187.99
#
# 4. Highest Production Season:
# Kharif with 46.31 tonnes
#
# 5. Rainfall vs Yield Correlation:
# 0.031
#
# 6. Fertilizer vs Yield Correlation:
# 0.0
#
# 7. Soil Moisture vs Yield Correlation:
# 0.011

# %%
final_findings = pd.DataFrame({
    'Finding': [
        'Highest Yield Season',
        'Highest Yielding Crop',
        'Highest Profit Crop',
        'Highest Production Season',
        'Best Irrigation Method for Yield',
        'Best Irrigation Method for Water Efficiency'
    ],
    'Result': [
        season_yield.idxmax(),
        crop_yield.idxmax(),
        crop_profit.idxmax(),
        season_production.idxmax(),
        irrigation_yield.idxmax(),
        water_efficiency.idxmax()
    ]
})

final_findings
# Out:
#                                        Finding     Result
# 0                         Highest Yield Season     Kharif
# 1                        Highest Yielding Crop  Sugarcane
# 2                          Highest Profit Crop  Sugarcane
# 3                    Highest Production Season     Kharif
# 4             Best Irrigation Method for Yield       Drip
# 5  Best Irrigation Method for Water Efficiency    Rainfed

# %%
df.to_csv('cleaned_seasonal_agriculture_dataset.csv', index=False)

print("Cleaned dataset saved successfully!")
# Out:
# Cleaned dataset saved successfully!

# %%
# 1. Average Yield by Season
season_yield.plot(kind='bar')
plt.title('Average Crop Yield by Season')
plt.xlabel('Season')
plt.ylabel('Yield (Tonnes/Ha)')
plt.xticks(rotation=0)
plt.show()


# 2. Average Yield by Crop
crop_yield.sort_values().plot(kind='bar')
plt.title('Average Crop Yield by Crop')
plt.xlabel('Crop')
plt.ylabel('Yield (Tonnes/Ha)')
plt.xticks(rotation=45)
plt.show()


# 3. Average Profit by Crop
crop_profit.sort_values().plot(kind='bar')
plt.title('Average Profit by Crop')
plt.xlabel('Crop')
plt.ylabel('Profit (INR)')
plt.xticks(rotation=45)
plt.show()


# 4. Average Water Efficiency by Irrigation Method
water_efficiency.plot(kind='bar')
plt.title('Water Efficiency by Irrigation Method')
plt.xlabel('Irrigation Method')
plt.ylabel('Water Efficiency (Tonnes per 1000 m³)')
plt.xticks(rotation=0)
plt.show()
